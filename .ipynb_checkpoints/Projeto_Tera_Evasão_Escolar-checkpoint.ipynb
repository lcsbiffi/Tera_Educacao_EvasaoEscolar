# %% [markdown]
# <a href="https://colab.research.google.com/github/lcsbiffi/projetoTera_evasaoescolar/blob/main/Projeto_Tera_Evas%C3%A3o_Escolar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto Tera - Evasão Escolar

# %% [markdown]
# **Problema**
#
# Prever a evasão escolar e suas principais variáveis para que gestores escolares atuem ativamente em políticas de combate.
#
#
# **Hipóteses**
#
# 1) As principais variáveis de evasão estão relacionadas a renda familiar.
#
# 2) A variável de transporte está diretamente relacionada à evasão.
#
# 3) Maternidade e paternidade na adolescência está entre as principais variáveis de evasão.
#
# 4) A falta de professores está relacionada a evasão.

# %% [markdown]
# ## Carregando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Importando bancos de dados

# %%
ideb = pd.read_csv('.\BDs\ideb_escola.csv')
inep = pd.read_csv('.\BDs\inep.csv')

# %%
censo = pd.read_csv('.\BDs\censo_escolar.csv')

# %% [markdown]
# # Analisando o df do Ideb

# %% [markdown]
# **Legenda**
#
# *ano* - Ano
#
# *sigla-uf* - Sigla da Unidade da Federação
#
# *id_município* - ID Município - IBGE 7 Dígitos
#
# *id_escola* - ID Escola
#
# *rede* - Rede Escolar
#
# *ensino* - Tipo de Ensino (fundamental ou médio)
#
# *anos_escolares* - Anos escolares (Iniciais (1-5), Finais (6-9), Todos (1-4) <- Ensino Médio)
#
# *taxa_aprovação* - Taxa de Aprovação (0 a 100)
#
# *indicador_rendimento* - Indicador de Rendimento (P)
#
# *nota_saeb_matematica* - Nota SAEB - Matemática
#
# *nota_saeb_lingua_portuguesa* - Nota SAEB - Português
#
# *nota_saeb_media_padronizada* - Nota SAEB - Média Padronizada (N)
#
# *ideb* - IDEB (Média Padronizada (N) X Indicador de Rendimento (P)
#
# *projecao* - Projeção (sei lá)

# %%
ideb.head()
# Out:
#     ano sigla_uf  id_municipio  id_escola       rede       ensino  \
# 0  2005       AC       1200013   12008966  municipal  fundamental
# 1  2005       AC       1200013   12008966  municipal  fundamental
# 2  2005       AC       1200013   12009156  municipal  fundamental
# 3  2005       AC       1200013   12009156  municipal  fundamental
# 4  2005       AC       1200013   12009164   estadual  fundamental
#
#    anos_escolares  taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0    finais (6-9)             NaN                   NaN                   NaN
# 1  iniciais (1-5)             NaN                   NaN                   NaN
# 2    finais (6-9)             NaN                   NaN                   NaN
# 3  iniciais (1-5)             NaN                   NaN                   NaN
# 4    finais (6-9)             NaN                   NaN                   NaN
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                          NaN                          NaN   NaN       NaN
# 1                          NaN                          NaN   NaN       NaN
# 2                          NaN                          NaN   NaN       NaN
# 3                          NaN                          NaN   NaN       NaN
# 4                          NaN                          NaN   NaN       NaN

# %%
ideb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1027767 entries, 0 to 1027766
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   ano                          1027767 non-null  int64
#  1   sigla_uf                     1027767 non-null  object
#  2   id_municipio                 1027767 non-null  int64
#  3   id_escola                    1027767 non-null  int64
#  4   rede                         1027767 non-null  object
#  5   ensino                       1027767 non-null  object
#  6   anos_escolares               1027767 non-null  object
#  7   taxa_aprovacao               619628 non-null   float64
#  8   indicador_rendimento         619580 non-null   float64
#  9   nota_saeb_matematica         488139 non-null   float64
#  10  nota_saeb_lingua_portuguesa  488139 non-null   float64
#  11  nota_saeb_media_padronizada  556480 non-null   float64
#  12  ideb                         556306 non-null   float64
#  13  projecao                     705363 non-null   float64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 109.8+ MB

# %% [markdown]
# Temos valores NaN nas seguintes colunas:
#
# - taxa_aprovacao
# - indicador_rendimento
# - nota_saeb_matematica
# - nota_saeb_lingua_portuguesa
# - nota_saeb_media_padronizada
# - ideb
# - projecao

# %%
ideb.describe(include = 'all').round(1)
# Out:
#               ano sigla_uf  id_municipio   id_escola       rede       ensino  \
# count   1027767.0  1027767     1027767.0   1027767.0    1027767      1027767
# unique        NaN       27           NaN         NaN          4            2
# top           NaN       SP           NaN         NaN  municipal  fundamental
# freq          NaN   130434           NaN         NaN     645582       965727
# mean       2013.4      NaN     3088825.9  30875714.7        NaN          NaN
# std           5.2      NaN      995739.8   9926413.0        NaN          NaN
# min        2005.0      NaN     1100015.0  11000058.0        NaN          NaN
# 25%        2009.0      NaN     2311306.0  23197269.0        NaN          NaN
# 50%        2013.0      NaN     3114402.0  31044164.0        NaN          NaN
# 75%        2017.0      NaN     3550308.0  35436690.0        NaN          NaN
# max        2021.0      NaN     5300108.0  53082001.0        NaN          NaN
#
#         anos_escolares  taxa_aprovacao  indicador_rendimento  \
# count          1027767        619628.0              619580.0
# unique               3             NaN                   NaN
# top     iniciais (1-5)             NaN                   NaN
# freq            559242             NaN                   NaN
# mean               NaN            86.7                   0.9
# std                NaN            11.4                   0.1
# min                NaN             0.0                   0.0
# 25%                NaN            80.5                   0.8
# 50%                NaN            89.5                   0.9
# 75%                NaN            95.7                   1.0
# max                NaN           100.0                   1.0
#
#         nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# count               488139.0                     488139.0
# unique                   NaN                          NaN
# top                      NaN                          NaN
# freq                     NaN                          NaN
# mean                   222.2                        211.5
# std                     34.8                         37.5
# min                     99.9                        103.7
# 25%                    196.1                        181.7
# 50%                    223.9                        212.6
# 75%                    246.6                        239.0
# max                    432.7                        377.8
#
#         nota_saeb_media_padronizada      ideb  projecao
# count                      556480.0  556306.0  705363.0
# unique                          NaN       NaN       NaN
# top                             NaN       NaN       NaN
# freq                            NaN       NaN       NaN
# mean                            5.0       4.4       4.7
# std                             0.9       1.2       1.1
# min                             1.4       0.1       0.6
# 25%                             4.4       3.6       3.9
# 50%                             4.9       4.3       4.7
# 75%                             5.6       5.2       5.4
# max                             9.9       9.9       9.5

# %%
ideb_anos = ideb['ano'].value_counts()
print(ideb_anos)
# Out:
# 2017    127983
# 2019    127983
# 2021    127983
# 2005    107303
# 2007    107303
# 2009    107303
# 2011    107303
# 2013    107303
# 2015    107303
# Name: ano, dtype: int64

# %% [markdown]
# Temos dados de escolas nos anos:
#
# - 2005
# - 2007
# - 2009
# - 2011
# - 2013
# - 2015 (ano com menos observações)
# - 2017 (ano com mais observações)
# - 2019
# - 2021

# %%
ideb_ensino = ideb['ensino'].value_counts(normalize=True)*100
print(ideb_ensino)
# Out:
# fundamental    93.963612
# medio           6.036388
# Name: ensino, dtype: float64

# %%
ideb_anos_escolares = ideb['anos_escolares'].value_counts()
print(ideb_anos_escolares)
# Out:
# iniciais (1-5)    559242
# finais (6-9)      406485
# todos (1-4)        62040
# Name: anos_escolares, dtype: int64

# %% [markdown]
# Maioria das observações (93%) são de *turmas do Ensino Fundamental*

# %%
ideb_em_bool = ideb['anos_escolares'] == 'todos (1-4)'
ideb_em = ideb[ideb_em_bool]
print(ideb_em)
# Out:
#           ano sigla_uf  id_municipio  id_escola      rede ensino  \
# 643828   2017       AC       1200013   12018422  estadual  medio
# 643829   2017       AC       1200013   12021768  estadual  medio
# 643835   2017       AC       1200013   12128236  estadual  medio
# 643839   2017       AC       1200054   12015946  estadual  medio
# 643845   2017       AC       1200104   12016284  estadual  medio
# ...       ...      ...           ...        ...       ...    ...
# 1027737  2021       TO       1722081   17009995  estadual  medio
# 1027742  2021       TO       1722081   17010020  estadual  medio
# 1027751  2021       TO       1722107   17010322  estadual  medio
# 1027754  2021       TO       1722107   17010330  estadual  medio
# 1027764  2021       TO       1722107   17010462  estadual  medio
#
#         anos_escolares  taxa_aprovacao  indicador_rendimento  \
# 643828     todos (1-4)            89.7              0.894401
# 643829     todos (1-4)            74.6              0.753821
# 643835     todos (1-4)             NaN                   NaN
# 643839     todos (1-4)            82.9              0.836626
# 643845     todos (1-4)            95.3              0.958307
# ...                ...             ...                   ...
# 1027737    todos (1-4)             NaN                   NaN
# 1027742    todos (1-4)             NaN                   NaN
# 1027751    todos (1-4)             NaN                   NaN
# 1027754    todos (1-4)             NaN                   NaN
# 1027764    todos (1-4)             NaN                   NaN
#
#          nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# 643828                 270.64                       258.95
# 643829                    NaN                          NaN
# 643835                    NaN                          NaN
# 643839                    NaN                          NaN
# 643845                 264.76                       272.42
# ...                       ...                          ...
# 1027737                   NaN                          NaN
# 1027742                   NaN                          NaN
# 1027751                   NaN                          NaN
# 1027754                   NaN                          NaN
# 1027764                   NaN                          NaN
#
#          nota_saeb_media_padronizada  ideb  projecao
# 643828                      4.367425   3.9       NaN
# 643829                           NaN   NaN       NaN
# 643835                           NaN   NaN       NaN
# 643839                           NaN   NaN       NaN
# 643845                      4.486338   4.3       NaN
# ...                              ...   ...       ...
# 1027737                          NaN   NaN       NaN
# 1027742                          NaN   NaN       NaN
# 1027751                          NaN   NaN       4.7
# 1027754                          NaN   NaN       3.9
# 1027764                          NaN   NaN       NaN
#
# [62040 rows x 14 columns]

# %% [markdown]
# Confirmando aqui que o valor *todos (1-4)* da coluna *anos_escolares* se refere ao **ensino médio**

# %% [markdown]
# ## Arrumando valores NaN em cada Estado

# %% [markdown]
# Primeiro, vamos criar DataFrames separados para cada estado.

# %%
# Checando quais as siglas
ideb['sigla_uf'].value_counts()
# Out:
# SP    130434
# MG     99678
# BA     91995
# RS     70107
# MA     62844
# CE     61152
# RJ     57183
# PA     54213
# PR     47964
# PE     47484
# SC     39036
# GO     32241
# PI     30117
# PB     27693
# AM     23148
# RN     21585
# MT     20739
# AL     19974
# ES     18351
# SE     14583
# MS     14148
# TO     12486
# RO     10698
# DF      6105
# AC      5202
# AP      4869
# RR      3738
# Name: sigla_uf, dtype: int64

# %% [markdown]
# ## São Paulo (SP)

# %%
colunas = ['taxa_aprovacao', 'indicador_rendimento', 'nota_saeb_matematica', 'nota_saeb_lingua_portuguesa', 'nota_saeb_media_padronizada', 'ideb']
df_SP = ideb.loc[ideb['sigla_uf'] == "SP"]
df_SP[colunas].describe()
# Out:
#        taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# count    88752.000000          88750.000000          69704.000000
# mean        94.064977              0.939289            236.406227
# std          5.844558              0.060461             28.920474
# min          0.000000              0.122145            131.820000
# 25%         91.500000              0.913416            217.750000
# 50%         95.800000              0.957283            237.690000
# 75%         98.400000              0.983575            255.070000
# max        100.000000              1.000000            432.670000
#
#        nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada          ideb
# count                 69704.000000                 80440.000000  80432.000000
# mean                    225.164133                     5.451570      5.159987
# std                      33.584867                     0.898935      1.020607
# min                     122.200000                     2.386667      0.600000
# 25%                     199.170000                     4.765667      4.400000
# 50%                     226.440000                     5.326333      5.100000
# 75%                     248.330000                     6.077823      5.900000
# max                     377.850000                     9.102075      9.000000

# %%
df_SP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130434 entries, 92937 to 1026180
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ano                          130434 non-null  int64
#  1   sigla_uf                     130434 non-null  object
#  2   id_municipio                 130434 non-null  int64
#  3   id_escola                    130434 non-null  int64
#  4   rede                         130434 non-null  object
#  5   ensino                       130434 non-null  object
#  6   anos_escolares               130434 non-null  object
#  7   taxa_aprovacao               88752 non-null   float64
#  8   indicador_rendimento         88750 non-null   float64
#  9   nota_saeb_matematica         69704 non-null   float64
#  10  nota_saeb_lingua_portuguesa  69704 non-null   float64
#  11  nota_saeb_media_padronizada  80440 non-null   float64
#  12  ideb                         80432 non-null   float64
#  13  projecao                     93332 non-null   float64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 14.9+ MB

# %%
df_SP.isnull().sum()
# Out:
# ano                                0
# sigla_uf                           0
# id_municipio                       0
# id_escola                          0
# rede                               0
# ensino                             0
# anos_escolares                     0
# taxa_aprovacao                 41682
# indicador_rendimento           41684
# nota_saeb_matematica           60730
# nota_saeb_lingua_portuguesa    60730
# nota_saeb_media_padronizada    49994
# ideb                           50002
# projecao                       37102
# dtype: int64

# %%
for row in df_SP:
    for coluna in colunas:
        df_SP[coluna].fillna((df_SP[coluna].mean()), inplace = True)
# Out:
# C:\Users\lcsbi\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df_SP.head()
# Out:
#         ano sigla_uf  id_municipio  id_escola       rede       ensino  \
# 92937  2005       SP       3500105   35030806   estadual  fundamental
# 92938  2005       SP       3500105   35031045   estadual  fundamental
# 92939  2005       SP       3500105   35031112   estadual  fundamental
# 92940  2005       SP       3500105   35079911  municipal  fundamental
# 92941  2005       SP       3500105   35079923  municipal  fundamental
#
#        anos_escolares  taxa_aprovacao  indicador_rendimento  \
# 92937    finais (6-9)       94.064977              0.939289
# 92938    finais (6-9)       94.064977              0.939289
# 92939    finais (6-9)       94.064977              0.939289
# 92940  iniciais (1-5)       90.500000              0.901503
# 92941  iniciais (1-5)       94.200000              0.939028
#
#        nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# 92937            236.406227                   225.164133
# 92938            236.406227                   225.164133
# 92939            236.406227                   225.164133
# 92940            184.160000                   177.780000
# 92941            171.970000                   168.770000
#
#        nota_saeb_media_padronizada      ideb  projecao
# 92937                     5.451570  5.159987       NaN
# 92938                     5.451570  5.159987       NaN
# 92939                     5.451570  5.159987       NaN
# 92940                     4.711114  4.200000       NaN
# 92941                     4.314822  4.100000       NaN

# %%
df_SP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130434 entries, 92937 to 1026180
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ano                          130434 non-null  int64
#  1   sigla_uf                     130434 non-null  object
#  2   id_municipio                 130434 non-null  int64
#  3   id_escola                    130434 non-null  int64
#  4   rede                         130434 non-null  object
#  5   ensino                       130434 non-null  object
#  6   anos_escolares               130434 non-null  object
#  7   taxa_aprovacao               130434 non-null  float64
#  8   indicador_rendimento         130434 non-null  float64
#  9   nota_saeb_matematica         130434 non-null  float64
#  10  nota_saeb_lingua_portuguesa  130434 non-null  float64
#  11  nota_saeb_media_padronizada  130434 non-null  float64
#  12  ideb                         130434 non-null  float64
#  13  projecao                     93332 non-null   float64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 14.9+ MB

# %%
# Renomeando
ideb_sp = df_SP.drop('projecao', axis=1)
ideb_sp.head()
# Out:
#         ano sigla_uf  id_municipio  id_escola       rede       ensino  \
# 92937  2005       SP       3500105   35030806   estadual  fundamental
# 92938  2005       SP       3500105   35031045   estadual  fundamental
# 92939  2005       SP       3500105   35031112   estadual  fundamental
# 92940  2005       SP       3500105   35079911  municipal  fundamental
# 92941  2005       SP       3500105   35079923  municipal  fundamental
#
#        anos_escolares  taxa_aprovacao  indicador_rendimento  \
# 92937    finais (6-9)       94.064977              0.939289
# 92938    finais (6-9)       94.064977              0.939289
# 92939    finais (6-9)       94.064977              0.939289
# 92940  iniciais (1-5)       90.500000              0.901503
# 92941  iniciais (1-5)       94.200000              0.939028
#
#        nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# 92937            236.406227                   225.164133
# 92938            236.406227                   225.164133
# 92939            236.406227                   225.164133
# 92940            184.160000                   177.780000
# 92941            171.970000                   168.770000
#
#        nota_saeb_media_padronizada      ideb
# 92937                     5.451570  5.159987
# 92938                     5.451570  5.159987
# 92939                     5.451570  5.159987
# 92940                     4.711114  4.200000
# 92941                     4.314822  4.100000

# %% [markdown]
# ## Matriz de correlação (com os dados tratados)

# %%
corr = ideb_tratado.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_15775_row0_col0, #T_15775_row1_col1, #T_15775_row1_col2, #T_15775_row2_col1, #T_15775_row2_col2, #T_15775_row3_col3, #T_15775_row4_col4, #T_15775_row5_col5, #T_15775_row6_col6, #T_15775_row7_col7, #T_15775_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_15775_row0_col1, #T_15775_row0_col2, #T_15775_row0_col3, #T_15775_row0_col4, #T_15775_row0_col5, #T_15775_row0_col7, #T_15775_row0_col8, #T_15775_row1_col0, #T_15775_row2_col0, #T_15775_row3_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_15775_row0_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_15775_row1_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_15775_row1_col4, #T_15775_row2_col4, #T_15775_row6_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_15775_row1_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_15775_row1_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_15775_row1_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_15775_row1_col8 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_15775_row2_col3, #T_15775_row4_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_15775_row2_col5, #T_15775_row3_col1, #T_15775_row3_col2, #T_15775_row4_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_15775_row2_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_15775_row2_col7 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_15775_row2_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_15775_row3_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_15775_row3_col4, #T_15775_row4_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_15775_row3_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_15775_row3_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_15775_row3_col8 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_15775_row4_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_15775_row4_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_15775_row4_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_15775_row4_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_15775_row4_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_15775_row5_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_15775_row5_col1, #T_15775_row5_col2, #T_15775_row5_col8, #T_15775_row8_col1, #T_15775_row8_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_15775_row5_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_15775_row5_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_15775_row5_col6 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_15775_row5_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_15775_row6_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_15775_row6_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_15775_row6_col2, #T_15775_row8_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_15775_row6_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_15775_row6_col5 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_15775_row6_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_15775_row6_col8, #T_15775_row8_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_15775_row7_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_15775_row7_col1, #T_15775_row7_col2, #T_15775_row8_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_15775_row7_col3 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_15775_row7_col4, #T_15775_row7_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_15775_row7_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_15775_row7_col8, #T_15775_row8_col7 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_15775_row8_col3 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_15775_row8_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# </style>
# <table id="T_15775_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ano</th>
#       <th class="col_heading level0 col1" >id_municipio</th>
#       <th class="col_heading level0 col2" >id_escola</th>
#       <th class="col_heading level0 col3" >taxa_aprovacao</th>
#       <th class="col_heading level0 col4" >indicador_rendimento</th>
#       <th class="col_heading level0 col5" >nota_saeb_matematica</th>
#       <th class="col_heading level0 col6" >nota_saeb_lingua_portuguesa</th>
#       <th class="col_heading level0 col7" >nota_saeb_media_padronizada</th>
#       <th class="col_heading level0 col8" >ideb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15775_level0_row0" class="row_heading level0 row0" >ano</th>
#       <td id="T_15775_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T
# * **Nível VII** - Neste nível, os estudantes estão de um a dois desvios-padrão acima da média nacional do Inse. Considerando a maioria dos estudantes, a mãe/responsável e/ou o pai/responsável têm ensino médio completo ou ensino superior completo. A maioria possui uma geladeira, três ou mais quartos, um banheiro, wi-fi, máquina de lavar roupas, freezer, um carro, garagem, forno de micro-ondas, mesa para estudos e aspirador de pó. Parte dos estudantes deste nível passa a ter também dois ou mais carros, três ou mais banheiros e duas ou mais geladeiras.
# * **Nível VIII** - Este é o nível superior da escala, no qual os estudantes estão dois desvios-padrão ou mais acima da média nacional do Inse. Considerando a maioria dos estudantes, a mãe/responsável e/ou o pai/responsável têm ensino superior completo. Além de possuírem os bens dos níveis anteriores, a maioria dos estudantes deste nível passa a ter duas ou mais geladeiras, dois ou mais computadores, três ou mais televisões, três ou mais banheiros e dois ou mais carros.

# %%
inse_2019 = pd.read_excel('.\BDs\inse_2019.xlsx')

# %%
inse_sp = inse_2019[inse_2019['NOME_UF'] == 'São Paulo'].drop(['CO_UF'], axis=1)
inse_sp.head()
# Out:
#        CO_ESCOLA                          NOME_ESCOLA    NOME_UF  \
# 43415   35030806                         HELEN KELLER  São Paulo
# 43416   35031045                 DURVALINO GRION PROF  São Paulo
# 43417   35031082       EUDECIO LUIZ VICENTE PROF ETEC  São Paulo
# 43418   35031100      HERVAL BELLUSCI ENGENHEIRO ETEC  São Paulo
# 43419   35031112  FLEURIDES CAVALLINI MENECHINO PROFA  São Paulo
#
#        CO_MUNICIPIO NOME_MUNICIPIO  ID_AREA  TP_DEPENDENCIA  TP_LOCALIZACAO  \
# 43415       3500105     Adamantina        2               2               1
# 43416       3500105     Adamantina        2               2               1
# 43417       3500105     Adamantina        2               2               1
# 43418       3500105     Adamantina        2               2               2
# 43419       3500105     Adamantina        2               2               1
#
#        QTD_ALUNOS_INSE  INSE_VALOR_ABSOLUTO INSE_CLASSIFICACAO  PC_NIVEL_1  \
# 43415              123                 5.31            Nível V         0.0
# 43416              110                 5.36            Nível V         0.0
# 43417              140                 5.78           Nível VI         0.0
# 43418               19                 5.39            Nível V         0.0
# 43419              146                 5.54           Nível VI         0.0
#
#        PC_NIVEL_2  PC_NIVEL_3  PC_NIVEL_4  PC_NIVEL_5  PC_NIVEL_6  PC_NIVEL_7  \
# 43415        4.83        7.75       18.56       33.39       22.45       12.31
# 43416        0.00        9.36       14.40       38.21       23.56       13.46
# 43417        2.17        1.42        9.94       17.16       30.66       33.61
# 43418        0.00       10.53       15.79       26.32       31.58       10.53
# 43419        1.94        6.69       16.58       21.18       19.57       32.10
#
#        PC_NIVEL_8
# 43415        0.71
# 43416        1.02
# 43417        5.02
# 43418        5.26
# 43419        1.94

# %%
inse_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10202 entries, 43415 to 53616
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CO_ESCOLA            10202 non-null  int64
#  1   NOME_ESCOLA          10202 non-null  object
#  2   NOME_UF              10202 non-null  object
#  3   CO_MUNICIPIO         10202 non-null  int64
#  4   NOME_MUNICIPIO       10202 non-null  object
#  5   ID_AREA              10202 non-null  int64
#  6   TP_LOCALIZACAO       10202 non-null  int64
#  7   QTD_ALUNOS_INSE      10202 non-null  int64
#  8   INSE_VALOR_ABSOLUTO  10202 non-null  float64
#  9   INSE_CLASSIFICACAO   10202 non-null  object
#  10  PC_NIVEL_1           10202 non-null  float64
#  11  PC_NIVEL_2           10202 non-null  float64
#  12  PC_NIVEL_3           10202 non-null  float64
#  13  PC_NIVEL_4           10202 non-null  float64
#  14  PC_NIVEL_5           10202 non-null  float64
#  15  PC_NIVEL_6           10202 non-null  float64
#  16  PC_NIVEL_7           10202 non-null  float64
#  17  PC_NIVEL_8           10202 non-null  float64
# dtypes: float64(9), int64(5), object(4)
# memory usage: 1.5+ MB

# %%
inse_sp.rename(columns = {'CO_ESCOLA' : 'id_escola'}, inplace=True)
inse_sp.head()
# Out:
#        id_escola                          NOME_ESCOLA    NOME_UF  \
# 43415   35030806                         HELEN KELLER  São Paulo
# 43416   35031045                 DURVALINO GRION PROF  São Paulo
# 43417   35031082       EUDECIO LUIZ VICENTE PROF ETEC  São Paulo
# 43418   35031100      HERVAL BELLUSCI ENGENHEIRO ETEC  São Paulo
# 43419   35031112  FLEURIDES CAVALLINI MENECHINO PROFA  São Paulo
#
#        CO_MUNICIPIO NOME_MUNICIPIO  ID_AREA  TP_DEPENDENCIA  TP_LOCALIZACAO  \
# 43415       3500105     Adamantina        2               2               1
# 43416       3500105     Adamantina        2               2               1
# 43417       3500105     Adamantina        2               2               1
# 43418       3500105     Adamantina        2               2               2
# 43419       3500105     Adamantina        2               2               1
#
#        QTD_ALUNOS_INSE  INSE_VALOR_ABSOLUTO INSE_CLASSIFICACAO  PC_NIVEL_1  \
# 43415              123                 5.31            Nível V         0.0
# 43416              110                 5.36            Nível V         0.0
# 43417              140                 5.78           Nível VI         0.0
# 43418               19                 5.39            Nível V         0.0
# 43419              146                 5.54           Nível VI         0.0
#
#        PC_NIVEL_2  PC_NIVEL_3  PC_NIVEL_4  PC_NIVEL_5  PC_NIVEL_6  PC_NIVEL_7  \
# 43415        4.83        7.75       18.56       33.39       22.45       12.31
# 43416        0.00        9.36       14.40       38.21       23.56       13.46
# 43417        2.17        1.42        9.94       17.16       30.66       33.61
# 43418        0.00       10.53       15.79       26.32       31.58       10.53
# 43419        1.94        6.69       16.58       21.18       19.57       32.10
#
#        PC_NIVEL_8
# 43415        0.71
# 43416        1.02
# 43417        5.02
# 43418        5.26
# 43419        1.94

# %% [markdown]
# # Analisando o df do INEP (Indicadores Educacionais)

# %% [markdown]
# ## CONTINUAR DAQUI

# %% [markdown]
# Legenda
#
# * *ano* - Ano
# * *id_municipio* - ID do município (7 dígitos)
# * *id_escola* - ID da Escola
# * *localizacao* - Localização (rural ou urbana)
# * *rede* - Estadual ou Municipal
# * *atu_ei* - Média de Alunos por Turma - Educação Infantil
# * *atu_ei_creche* - Média de Alunos por Turma - Educação Infantil - Creche
# * *atu_ei_pre_escola* - Média de Alunos por Turma - Educação Infantil - Pré escola
# * *atu_ef* - Média de Alunos por Turma - Ensino Fundamental (Turmas Unificadas inclusas no cálculo do indicador a partir de 2017)
# * *atu_ef_anos_iniciais* - Média de Alunos por Turma - Ensino Fundamental Anos Iniciais
# * *atu_ef_anos_finais* - Média de Alunos por Turma - Ensino Fundamental Anos Finais
# * *atu_ef_1_ano* - Média de Alunos por Turma - Ensino Fundamental 1º ano
# * *atu_ef_2_ano* - Média de Alunos por Turma - Ensino Fundamental 2º ano
# * *atu_ef_3_ano* - Média de Alunos por Turma - Ensino Fundamental 3º ano
# * *atu_ef_4_ano* - Média de Alunos por Turma - Ensino Fundamental 4º ano
# * *atu_ef_5_ano* - Média de Alunos por Turma - Ensino Fundamental 5º ano
# * *atu_ef_6_ano* - Média de Alunos por Turma - Ensino Fundamental 6º ano

# %%
colunas = ['atu_ei', 'atu_ei_creche', 'atu_ei_pre_escola', 'atu_ef', 'atu_ef_anos_iniciais', 'atu_ef_anos_finais', 'atu_ef_1_ano', 'atu_ef_2_ano', 'atu_ef_3_ano', 'atu_ef_4_ano', 'atu_ef_5_ano', 'atu_ef_6_ano', 'atu_ef_7_ano', 'atu_ef_8_ano', 'atu_ef_9_ano', 'atu_ef_turmas_unif_multi_fluxo', 'had_ei', 'had_ei_creche', 'had_ei_pre_escola', 'had_ef', 'had_ef_anos_iniciais', 'had_ef_anos_finais', 'had_ef_1_ano', 'had_ef_2_ano', 'had_ef_3_ano', 'had_ef_4_ano', 'had_ef_5_ano', 'had_ef_6_ano', 'had_ef_7_ano', 'had_ef_8_ano', 'had_ef_9_ano', 'tdi_ef', 'tdi_ef_anos_iniciais', 'tdi_ef_anos_finais', 'tdi_ef_1_ano', 'tdi_ef_2_ano', 'tdi_ef_3_ano', 'tdi_ef_4_ano', 'tdi_ef_5_ano', 'tdi_ef_6_ano', 'tdi_ef_7_ano', 'tdi_ef_8_ano', 'tdi_ef_9_ano', 'taxa_aprovacao_ef', 'taxa_aprovacao_ef_anos_iniciais', 'taxa_aprovacao_ef_anos_finais', 'taxa_aprovacao_ef_1_ano', 'taxa_aprovacao_ef_2_ano', 'taxa_aprovacao_ef_3_ano', 'taxa_aprovacao_ef_4_ano', 'taxa_aprovacao_ef_5_ano', 'taxa_aprovacao_ef_6_ano', 'taxa_aprovacao_ef_7_ano', 'taxa_aprovacao_ef_8_ano', 'taxa_aprovacao_ef_9_ano', 'taxa_reprovacao_ef', 'taxa_reprovacao_ef_anos_iniciais', 'taxa_reprovacao_ef_anos_finais', 'taxa_reprovacao_ef_1_ano', 'taxa_reprovacao_ef_2_ano', 'taxa_reprovacao_ef_3_ano', 'taxa_reprovacao_ef_4_ano', 'taxa_reprovacao_ef_5_ano', 'taxa_reprovacao_ef_6_ano', 'taxa_reprovacao_ef_7_ano', 'taxa_reprovacao_ef_8_ano', 'taxa_reprovacao_ef_9_ano', 'taxa_abandono_ef', 'taxa_abandono_ef_anos_iniciais', 'taxa_abandono_ef_anos_finais', 'taxa_abandono_ef_1_ano', 'taxa_abandono_ef_2_ano', 'taxa_abandono_ef_3_ano', 'taxa_abandono_ef_4_ano', 'taxa_abandono_ef_5
# 4           NaN           NaN           NaN  ...                    NaN
#
#    afd_eja_medio_grupo_3  afd_eja_medio_grupo_4  afd_eja_medio_grupo_5  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    ied_em_nivel_1  ied_em_nivel_2  ied_em_nivel_3  ied_em_nivel_4  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    ied_em_nivel_5  ied_em_nivel_6
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
#
# [5 rows x 63 columns]

# %%
inep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637557 entries, 0 to 2637556
# Data columns (total 63 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   ano                             int64
#  1   id_municipio                    int64
#  2   rede                            object
#  3   id_escola                       int64
#  4   localizacao                     object
#  5   atu_em                          float64
#  6   atu_em_1_ano                    float64
#  7   atu_em_2_ano                    float64
#  8   atu_em_3_ano                    float64
#  9   atu_em_4_ano                    float64
#  10  atu_em_nao_seriado              float64
#  11  had_em                          float64
#  12  had_em_1_ano                    float64
#  13  had_em_2_ano                    float64
#  14  had_em_3_ano                    float64
#  15  had_em_4_ano                    float64
#  16  had_em_nao_seriado              float64
#  17  tdi_em                          float64
#  18  tdi_em_1_ano                    float64
#  19  tdi_em_2_ano                    float64
#  20  tdi_em_3_ano                    float64
#  21  tdi_em_4_ano                    float64
#  22  taxa_aprovacao_em               float64
#  23  taxa_aprovacao_em_1_ano         float64
#  24  taxa_aprovacao_em_2_ano         float64
#  25  taxa_aprovacao_em_3_ano         float64
#  26  taxa_aprovacao_em_4_ano         float64
#  27  taxa_aprovacao_em_nao_seriado   float64
#  28  taxa_reprovacao_em              float64
#  29  taxa_reprovacao_em_1_ano        float64
#  30  taxa_reprovacao_em_2_ano        float64
#  31  taxa_reprovacao_em_3_ano        float64
#  32  taxa_reprovacao_em_4_ano        float64
#  33  taxa_reprovacao_em_nao_seriado  float64
#  34  taxa_abandono_em                float64
#  35  taxa_abandono_em_1_ano          float64
#  36  taxa_abandono_em_2_ano          float64
#  37  taxa_abandono_em_3_ano          float64
#  38  taxa_abandono_em_4_ano          float64
#  39  taxa_abandono_em_nao_seriado    float64
#  40  tnr_em                          float64
#  41  tnr_em_1_ano                    float64
#  42  tnr_em_2_ano                    float64
#  43  tnr_em_3_ano                    float64
#  44  tnr_em_4_ano                    float64
#  45  tnr_em_nao_seriado              float64
#  46  dsu_em                          float64
#  47  afd_em_grupo_1                  float64
#  48  afd_em_grupo_2                  float64
#  49  afd_em_grupo_3                  float64
#  50  afd_em_grupo_4                  float64
#  51  afd_em_grupo_5                  float64
#  52  afd_eja_medio_grupo_1           float64
#  53  afd_eja_medio_grupo_2           float64
#  54  afd_eja_medio_grupo_3           float64
#  55  afd_eja_medio_grupo_4           float64
#  56  afd_eja_medio_grupo_5           float64
#  57  ied_em_nivel_1                  float64
#  58  ied_em_nivel_2                  float64
#  59  ied_em_nivel_3                  float64
#  60  ied_em_nivel_4                  float64
#  61  ied_em_nivel_5                  float64
#  62  ied_em_nivel_6                  float64
# dtypes: float64(58), int64(3), object(2)
# memory usage: 1.2+ GB

# %%
inep['atu_em'].isnull

# %% [markdown]
# # Combinando os DFs do inep, inse e ideb

# %%
ideb_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130434 entries, 92937 to 1026180
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ano                          130434 non-null  int64
#  1   sigla_uf                     130434 non-null  object
#  2   id_municipio                 130434 non-null  int64
#  3   id_escola                    130434 non-null  int64
#  4   rede                         130434 non-null  object
#  5   ensino                       130434 non-null  object
#  6   anos_escolares               130434 non-null  object
#  7   taxa_aprovacao               130434 non-null  float64
#  8   indicador_rendimento         130434 non-null  float64
#  9   nota_saeb_matematica         130434 non-null  float64
#  10  nota_saeb_lingua_portuguesa  130434 non-null  float64
#  11  nota_saeb_media_padronizada  130434 non-null  float64
#  12  ideb                         130434 non-null  float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 13.9+ MB

# %%
inse_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10202 entries, 43415 to 53616
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CO_ESCOLA            10202 non-null  int64
#  1   NOME_ESCOLA          10202 non-null  object
#  2   NOME_UF              10202 non-null  object
#  3   CO_MUNICIPIO         10202 non-null  int64
#  4   NOME_MUNICIPIO       10202 non-null  object
#  5   ID_AREA              10202 non-null  int64
#  6   TP_DEPENDENCIA       10202 non-null  int64
#  7   TP_LOCALIZACAO       10202 non-null  int64
#  8   QTD_ALUNOS_INSE      10202 non-null  int64
#  9   INSE_VALOR_ABSOLUTO  10202 non-null  float64
#  10  INSE_CLASSIFICACAO   10202 non-null  object
#  11  PC_NIVEL_1           10202 non-null  float64
#  12  PC_NIVEL_2           10202 non-null  float64
#  13  PC_NIVEL_3           10202 non-null  float64
#  14  PC_NIVEL_4           10202 non-null  float64
#  15  PC_NIVEL_5           10202 non-null  float64
#  16  PC_NIVEL_6           10202 non-null  float64
#  17  PC_NIVEL_7           10202 non-null  float64
#  18  PC_NIVEL_8           10202 non-null  float64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 1.6+ MB

# %%
inep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637557 entries, 0 to 2637556
# Data columns (total 63 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   ano                             int64
#  1   id_municipio                    int64
#  2   rede                            object
#  3   id_escola                       int64
#  4   localizacao                     object
#  5   atu_em                          float64
#  6   atu_em_1_ano                    float64
#  7   atu_em_2_ano                    float64
#  8   atu_em_3_ano                    float64
#  9   atu_em_4_ano                    float64
#  10  atu_em_nao_seriado              float64
#  11  had_em                          float64
#  12  had_em_1_ano                    float64
#  13  had_em_2_ano                    float64
#  14  had_em_3_ano                    float64
#  15  had_em_4_ano                    float64
#  16  had_em_nao_seriado              float64
#  17  tdi_em                          float64
#  18  tdi_em_1_ano                    float64
#  19  tdi_em_2_ano                    float64
#  20  tdi_em_3_ano                    float64
#  21  tdi_em_4_ano                    float64
#  22  taxa_aprovacao_em               float64
#  23  taxa_aprovacao_em_1_ano         float64
#  24  taxa_aprovacao_em_2_ano         float64
#  25  taxa_aprovacao_em_3_ano         float64
#  26  taxa_aprovacao_em_4_ano         float64
#  27  taxa_aprovacao_em_nao_seriado   float64
#  28  taxa_reprovacao_em              float64
#  29  taxa_reprovacao_em_1_ano        float64
#  30  taxa_reprovacao_em_2_ano        float64
#  31  taxa_reprovacao_em_3_ano        float64
#  32  taxa_reprovacao_em_4_ano        float64
#  33  taxa_reprovacao_em_nao_seriado  float64
#  34  taxa_abandono_em                float64
#  35  taxa_abandono_em_1_ano          float64
#  36  taxa_abandono_em_2_ano          float64
#  37  taxa_abandono_em_3_ano          float64
#  38  taxa_abandono_em_4_ano          float64
#  39  taxa_abandono_em_nao_seriado    float64
#  40  tnr_em                          float64
#  41  tnr_em_1_ano                    float64
#  42  tnr_em_2_ano                    float64
#  43  tnr_em_3_ano                    float64
#  44  tnr_em_4_ano                    float64
#  45  tnr_em_nao_seriado              float64
#  46  dsu_em                          float64
#  47  afd_em_grupo_1                  float64
#  48  afd_em_grupo_2                  float64
#  49  afd_em_grupo_3                  float64
#  50  afd_em_grupo_4                  float64
#  51  afd_em_grupo_5                  float64
#  52  afd_eja_medio_grupo_1           float64
#  53  afd_eja_medio_grupo_2           float64
#  54  afd_eja_medio_grupo_3           float64
#  55  afd_eja_medio_grupo_4           float64
#  56  afd_eja_medio_grupo_5           float64
#  57  ied_em_nivel_1                  float64
#  58  ied_em_nivel_2                  float64
#  59  ied_em_nivel_3                  float64
#  60  ied_em_nivel_4                  float64
#  61  ied_em_nivel_5                  float64
#  62  ied_em_nivel_6                  float64
# dtypes: float64(58), int64(3), object(2)
# memory usage: 1.2+ GB

# %%
evasao_sp = ideb_sp.merge(inse_sp, how)

# %% [markdown]
# # CENSO ESCOLAR

# %%
censo = censo[censo['sigla_uf'] == 'SP']
censo.head()
# Out:
#           ano sigla_uf  id_municipio      rede   id_escola    id_turma  \
# 1809641  2009       SP     3508603.0  estadual  35013055.0  12853067.0
# 1809642  2009       SP     3508603.0  estadual  35013055.0  12853068.0
# 1809643  2009       SP     3508603.0  estadual  35013055.0  12853069.0
# 1809644  2009       SP     3508603.0  estadual  35013055.0  12853070.0
# 1809645  2009       SP     3508603.0  estadual  35013055.0  12853071.0
#
#          etapa_ensino  tipo_turma  hora_inicial  minuto_inicial  \
# 1809641          10.0         0.0           7.0             0.0
# 1809642           9.0         0.0           7.0             0.0
# 1809643          26.0         0.0           7.0             0.0
# 1809644           8.0         0.0          12.0            30.0
# 1809645          45.0         0.0          18.0            30.0
#
#          dia_semana_domingo  dia_semana_segunda  dia_semana_terca  \
# 1809641                 NaN                 NaN               NaN
# 1809642                 NaN                 NaN               NaN
# 1809643                 NaN                 NaN               NaN
# 1809644                 NaN                 NaN               NaN
# 1809645                 NaN                 NaN               NaN
#
#          dia_semana_quarta  dia_semana_quinta  dia_semana_sexta  \
# 1809641                NaN                NaN               NaN
# 1809642                NaN                NaN               NaN
# 1809643                NaN                NaN               NaN
# 1809644                NaN                NaN               NaN
# 1809645                NaN                NaN               NaN
#
#          dia_semana_sabado  numero_dias_atividade  numero_duracao_turma  \
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423166 entries, 1809641 to 2232806
# Data columns (total 76 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   ano                               423166 non-null  int64
#  1   sigla_uf                          423166 non-null  object
#  2   id_municipio                      423166 non-null  float64
#  3   rede                              423166 non-null  object
#  4   id_escola                         423166 non-null  float64
#  5   id_turma                          423166 non-null  float64
#  6   etapa_ensino                      413498 non-null  float64
#  7   tipo_turma                        423166 non-null  float64
#  8   hora_inicial                      423166 non-null  float64
#  9   minuto_inicial                    423166 non-null  float64
#  10  dia_semana_domingo                0 non-null       float64
#  11  dia_semana_segunda                0 non-null       float64
#  12  dia_semana_terca                  0 non-null       float64
#  13  dia_semana_quarta                 0 non-null       float64
#  14  dia_semana_quinta                 0 non-null       float64
#  15  dia_semana_sexta                  0 non-null       float64
#  16  dia_semana_sabado                 0 non-null       float64
#  17  numero_dias_atividade             9668 non-null    float64
#  18  numero_duracao_turma              423166 non-null  float64
#  19  tipo_atividade_1                  6606 non-null    float64
#  20  tipo_atividade_2                  2232 non-null    float64
#  21  tipo_atividade_3                  1993 non-null    float64
#  22  tipo_atividade_4                  1926 non-null    float64
#  23  tipo_atividade_5                  1739 non-null    float64
#  24  tipo_atividade_6                  1362 non-null    float64
#  25  id_curso_educacao_profissional    14539 non-null   float64
#  26  quantidade_matriculas             423166 non-null  float64
#  27  disciplina_lingua_portuguesa      423166 non-null  float64
#  28  disciplina_educacao_fisica        423166 non-null  float64
#  29  disciplina_artes                  423166 non-null  float64
#  30  disciplina_lingua_ingles          423166 non-null  float64
#  31  disciplina_lingua_espanhol        423166 non-null  float64
#  32  disciplina_lingua_frances         0 non-null       float64
#  33  disciplina_lingua_outra           423166 non-null  float64
#  34  disciplina_libras                 423166 non-null  float64
#  35  disciplina_lingua_indigena        423166 non-null  float64
#  36  disciplina_matematica             423166 non-null  float64
#  37  disciplina_ciencias               423166 non-null  float64
#  38  disciplina_fisica                 423166 non-null  float64
#  39  disciplina_quimica                423166 non-null  float64
#  40  disciplina_biologia               423166 non-null  float64
#  41  disciplina_historia               423166 non-null  float64
#  42  disciplina_geografia              423166 non-null  float64
#  43  disciplina_sociologia             0 non-null       float64
#  44  disciplina_filosofia              423166 non-null  float64
#  45  disciplina_estudos_sociais        423166 non-null  float64
#  46  disciplina_informatica_comp       423166 non-null  float64
#  47  disciplina_ensino_religioso       423166 non-null  float64
#  48  disciplina_profissionalizante     423166 non-null  float64
#  49  disciplina_pedagogicas            423166 non-null  float64
#  50  disciplina_outras                 423166 non-null  float64
#  51  tipo_localizacao                  423166 non-null  float64
#  52  tipo_categoria_escola_privada     114533 non-null  float64
#  53  conveniada_poder_publico          114533 non-null  float64
#  54  tipo_convenio_poder_publico       22326 non-null   float64
#  55  mantenedora_privada_emp           423166 non-null  float64
#  56  mantenedora_privada_ong           423166 non-null  float64
#  57  mantenedora_privada_sind          423166 non-null  float64
#  58  mantenedora_privada_sist_s        0 non-null       float64
#  59  mantenedora_privada_s_fins        423166 non-null  float64
#  60  tipo_regulamentacao               423166 non-null  float64
#  61  tipo_localizacao_diferenciada     423166 non-null  float64
#  62  educacao_indigena                 423166 non-null  float64
#  63  braille                           423166 non-null  float64
#  64  recursos_baixa_visao              423166 non-null  float64
#  65  processos_mentais                 423166 non-null  float64
#  66  orientacao_mobilidade             423166 non-null  float64
#  67  sinais                            423166 non-null  float64
#  68  comunicacao_alt_aument            423166 non-null  float64
#  69  enriquecimento_curricular         423166 non-null  float64
#  70  soroban                           423166 non-null  float64
#  71  informatica_acessivel             423166 non-null  float64
#  72  port_escrita                      423166 non-null  float64
#  73  autonomia_escolar                 423166 non-null  float64
#  74  disciplina_atendimento_especiais  423166 non-null  float64
#  75  disciplina_diver_socio_cultural   423166 non-null  float64
# dtypes: float64(73), int64(1), object(2)
# memory usage: 248.6+ MB

# %%
censo_turma = pd.read_csv('.\BDs\censo_turma.csv')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27460/764834816.py in <module>
# ----> 1 censo_turma = pd.read_csv('.\BDs\censo_turma.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1057             new_rows = len(index)
#    1058
# -> 1059         df = DataFrame(col_dict, columns=columns, index=index)
#    1060
#    1061         self._currow += new_rows
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     133
#     134     if typ == "block":
# --> 135         return create_block_manager_from_arrays(
#     136             arrays, arr_names, axes, consolidate=consolidate
#     137         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes, consolidate)
#    1776         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1777     if consolidate:
# -> 1778         mgr._consolidate_inplace()
#    1779     return mgr
#    1780
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     622     def _consolidate_inplace(self) -> None:
#     623         if not self.is_consolidated():
# --> 624             self.blocks = tuple(_consolidate(self.blocks))
#     625             self._is_consolidated = True
#     626             self._known_consolidated = True
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1972     new_blocks: list[Block] = []
#    1973     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1974         merged_blocks = _merge_blocks(
#    1975             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1976         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1999             # Sequence[Union[int, float, complex, str, bytes, generic]],
#    2000             # Sequence[Sequence[Any]], SupportsArray]]
# -> 2001             new_values = np.vstack([b.values for b in blocks])  # type: ignore[misc]
#    2002         else:
#    2003             bvals = [blk.values for blk in blocks]
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 14.1 GiB for an array with shape (65, 29046919) and data type float64
