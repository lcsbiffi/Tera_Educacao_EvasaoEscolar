# %% [markdown]
# <a href="https://colab.research.google.com/github/lcsbiffi/projetoTera_evasaoescolar/blob/main/Projeto_Tera_Evas%C3%A3o_Escolar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto Tera - Evasão Escolar

# %% [markdown]
# **Problema**
#
# Prever a evasão escolar e suas principais variáveis para que gestores escolares atuem ativamente em políticas de combate.
#
#
# **Hipóteses**
#
# 1) As principais variáveis de evasão estão relacionadas a renda familiar.
#
# 2) A variável de transporte está diretamente relacionada à evasão.
#
# 3) Maternidade e paternidade na adolescência está entre as principais variáveis de evasão.
#
# 4) A falta de professores está relacionada a evasão.

# %% [markdown]
# ## Carregando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importando bancos de dados

# %%
ideb = pd.read_csv('.\BDs\ideb.csv')
inep = pd.read_csv('.\BDs\inep.csv')

# %%
#censo = pd.read_csv('.\BDs\censo_escolar.csv', nrows=1000)

# %% [markdown]
# ## Analisando o df do Ideb

# %% [markdown]
# **Legenda**
#
# *ano* - Ano
#
# *sifla-uf* - Sigla da Unidade da Federação
#
# *id_município* - ID Município - IBGE 7 Dígitos
#
# *id_escola* - ID Escola
#
# *rede* - Rede Escolar
#
# *ensino* - Tipo de Ensino (fundamental ou médio)
#
# *anos_escolares* - Anos escolares (Iniciais (1-5), Finais (6-9), Todos (1-4) <- Ensino Médio)
#
# *taxa_aprovação* - Taxa de Aprovação (0 a 100)
#
# *indicador_rendimento* - Indicador de Rendimento (P)
#
# *nota_saeb_matematica* - Nota SAEB - Matemática
#
# *nota_saeb_lingua_portuguesa* - Nota SAEB - Português
#
# *nota_saeb_media_padronizada* - Nota SAEB - Média Padronizada (N)
#
# *ideb* - IDEB (Média Padronizada (N) X Indicador de Rendimento (P)
#
# *projecao* - Projeção (sei lá)

# %%
ideb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1027767 entries, 0 to 1027766
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   ano                          1027767 non-null  int64
#  1   sigla_uf                     1027767 non-null  object
#  2   id_municipio                 1027767 non-null  int64
#  3   id_escola                    1027767 non-null  int64
#  4   rede                         1027767 non-null  object
#  5   ensino                       1027767 non-null  object
#  6   anos_escolares               1027767 non-null  object
#  7   taxa_aprovacao               619628 non-null   float64
#  8   indicador_rendimento         619580 non-null   float64
#  9   nota_saeb_matematica         488139 non-null   float64
#  10  nota_saeb_lingua_portuguesa  488139 non-null   float64
#  11  nota_saeb_media_padronizada  556480 non-null   float64
#  12  ideb                         556306 non-null   float64
#  13  projecao                     705363 non-null   float64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 109.8+ MB

# %% [markdown]
# Temos valores NaN nas seguintes colunas:
#
# - taxa_aprovacao
# - indicador_rendimento
# - nota_saeb_matematica
# - nota_saeb_lingua_portuguesa
# - nota_saeb_media_padronizada
# - ideb
# - projecao

# %%
ideb.describe(include = 'all').round(1)
# Out:
#               ano sigla_uf  id_municipio   id_escola       rede       ensino  \
# count   1027767.0  1027767     1027767.0   1027767.0    1027767      1027767
# unique        NaN       27           NaN         NaN          4            2
# top           NaN       SP           NaN         NaN  municipal  fundamental
# freq          NaN   130434           NaN         NaN     645582       965727
# mean       2013.4      NaN     3088825.9  30875714.7        NaN          NaN
# std           5.2      NaN      995739.8   9926413.0        NaN          NaN
# min        2005.0      NaN     1100015.0  11000058.0        NaN          NaN
# 25%        2009.0      NaN     2311306.0  23197269.0        NaN          NaN
# 50%        2013.0      NaN     3114402.0  31044164.0        NaN          NaN
# 75%        2017.0      NaN     3550308.0  35436690.0        NaN          NaN
# max        2021.0      NaN     5300108.0  53082001.0        NaN          NaN
#
#         anos_escolares  taxa_aprovacao  indicador_rendimento  \
# count          1027767        619628.0              619580.0
# unique               3             NaN                   NaN
# top     iniciais (1-5)             NaN                   NaN
# freq            559242             NaN                   NaN
# mean               NaN            86.7                   0.9
# std                NaN            11.4                   0.1
# min                NaN             0.0                   0.0
# 25%                NaN            80.5                   0.8
# 50%                NaN            89.5                   0.9
# 75%                NaN            95.7                   1.0
# max                NaN           100.0                   1.0
#
#         nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# count               488139.0                     488139.0
# unique                   NaN                          NaN
# top                      NaN                          NaN
# freq                     NaN                          NaN
# mean                   222.2                        211.5
# std                     34.8                         37.5
# min                     99.9                        103.7
# 25%                    196.1                        181.7
# 50%                    223.9                        212.6
# 75%                    246.6                        239.0
# max                    432.7                        377.8
#
#         nota_saeb_media_padronizada      ideb  projecao
# count                      556480.0  556306.0  705363.0
# unique                          NaN       NaN       NaN
# top                             NaN       NaN       NaN
# freq                            NaN       NaN       NaN
# mean                            5.0       4.4       4.7
# std                             0.9       1.2       1.1
# min                             1.4       0.1       0.6
# 25%                             4.4       3.6       3.9
# 50%                             4.9       4.3       4.7
# 75%                             5.6       5.2       5.4
# max                             9.9       9.9       9.5

# %%
ideb_anos = ideb['ano'].value_counts()
print(ideb_anos)
# Out:
# 2017    127983
# 2019    127983
# 2021    127983
# 2005    107303
# 2007    107303
# 2009    107303
# 2011    107303
# 2013    107303
# 2015    107303
# Name: ano, dtype: int64

# %% [markdown]
# Temos dados de escolas nos anos:
#
# - 2005
# - 2007
# - 2009
# - 2011
# - 2013
# - 2015 (ano com menos observações)
# - 2017 (ano com mais observações)
# - 2019
# - 2021

# %%
ideb_ensino = ideb['ensino'].value_counts(normalize=True)*100
print(ideb_ensino)
# Out:
# fundamental    93.963612
# medio           6.036388
# Name: ensino, dtype: float64

# %%
ideb_anos_escolares = ideb['anos_escolares'].value_counts()
print(ideb_anos_escolares)
# Out:
# iniciais (1-5)    559242
# finais (6-9)      406485
# todos (1-4)        62040
# Name: anos_escolares, dtype: int64

# %% [markdown]
# Maioria das observações (93%) são de *turmas do Ensino Fundamental*

# %%
ideb_em_bool = ideb['anos_escolares'] == 'todos (1-4)'
ideb_em = ideb[ideb_em_bool]
print(ideb_em)
# Out:
#           ano sigla_uf  id_municipio  id_escola      rede ensino  \
# 643828   2017       AC       1200013   12018422  estadual  medio
# 643829   2017       AC       1200013   12021768  estadual  medio
# 643835   2017       AC       1200013   12128236  estadual  medio
# 643839   2017       AC       1200054   12015946  estadual  medio
# 643845   2017       AC       1200104   12016284  estadual  medio
# ...       ...      ...           ...        ...       ...    ...
# 1027737  2021       TO       1722081   17009995  estadual  medio
# 1027742  2021       TO       1722081   17010020  estadual  medio
# 1027751  2021       TO       1722107   17010322  estadual  medio
# 1027754  2021       TO       1722107   17010330  estadual  medio
# 1027764  2021       TO       1722107   17010462  estadual  medio
#
#         anos_escolares  taxa_aprovacao  indicador_rendimento  \
# 643828     todos (1-4)            89.7              0.894401
# 643829     todos (1-4)            74.6              0.753821
# 643835     todos (1-4)             NaN                   NaN
# 643839     todos (1-4)            82.9              0.836626
# 643845     todos (1-4)            95.3              0.958307
# ...                ...             ...                   ...
# 1027737    todos (1-4)             NaN                   NaN
# 1027742    todos (1-4)             NaN                   NaN
# 1027751    todos (1-4)             NaN                   NaN
# 1027754    todos (1-4)             NaN                   NaN
# 1027764    todos (1-4)             NaN                   NaN
#
#          nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# 643828                 270.64                       258.95
# 643829                    NaN                          NaN
# 643835                    NaN                          NaN
# 643839                    NaN                          NaN
# 643845                 264.76                       272.42
# ...                       ...                          ...
# 1027737                   NaN                          NaN
# 1027742                   NaN                          NaN
# 1027751                   NaN                          NaN
# 1027754                   NaN                          NaN
# 1027764                   NaN                          NaN
#
#          nota_saeb_media_padronizada  ideb  projecao
# 643828                      4.367425   3.9       NaN
# 643829                           NaN   NaN       NaN
# 643835                           NaN   NaN       NaN
# 643839                           NaN   NaN       NaN
# 643845                      4.486338   4.3       NaN
# ...                              ...   ...       ...
# 1027737                          NaN   NaN       NaN
# 1027742                          NaN   NaN       NaN
# 1027751                          NaN   NaN       4.7
# 1027754                          NaN   NaN       3.9
# 1027764                          NaN   NaN       NaN
#
# [62040 rows x 14 columns]

# %% [markdown]
# Confirmando aqui que o valor *todos (1-4)* da coluna *anos_escolares* se refere ao **ensino médio**

# %% [markdown]
# ## Checando os estados com maiores taxas de aprovação (CONTINUAR)

# %%
ideb_aprov = ideb[['sigla_uf', 'taxa_aprovacao']]
ideb_aprov = ideb_aprov.set_index('sigla_uf')
# Out:
#           taxa_aprovacao
# sigla_uf
# AC                   NaN
# AC                   NaN
# AC                   NaN
# AC                   NaN
# AC                   NaN
# AC                   NaN
# AC                  90.1
# AC                  83.7
# AC                   NaN
# AC                   NaN
# AC                  70.4
# AC                   NaN
# AC                   NaN
# AC                   NaN
# AC                   NaN
# AC                  68.8
# AC                  77.1
# AC                  81.1
# AC                   NaN
# AC                   NaN
# AC                   NaN
# AC                  76.2
# AC                  47.6
# AC                   NaN
# AC                  78.5

# %% [markdown]
# ## Matriz de correlação (com os dados NaN ainda, só pra ver)

# %%
corr = ideb.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4f66a_row0_col0, #T_4f66a_row1_col1, #T_4f66a_row1_col2, #T_4f66a_row2_col1, #T_4f66a_row2_col2, #T_4f66a_row3_col3, #T_4f66a_row4_col4, #T_4f66a_row5_col5, #T_4f66a_row6_col6, #T_4f66a_row7_col7, #T_4f66a_row8_col8, #T_4f66a_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4f66a_row0_col1, #T_4f66a_row0_col2, #T_4f66a_row1_col0, #T_4f66a_row1_col7, #T_4f66a_row1_col8, #T_4f66a_row2_col0, #T_4f66a_row2_col7, #T_4f66a_row2_col8, #T_4f66a_row3_col5, #T_4f66a_row3_col6, #T_4f66a_row6_col3, #T_4f66a_row6_col4, #T_4f66a_row6_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4f66a_row0_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_4f66a_row0_col4, #T_4f66a_row0_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_4f66a_row0_col5, #T_4f66a_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_4f66a_row0_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_4f66a_row0_col7, #T_4f66a_row5_col9 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_4f66a_row0_col9, #T_4f66a_row5_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_4f66a_row1_col3, #T_4f66a_row2_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_4f66a_row1_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4f66a_row1_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4f66a_row1_col6, #T_4f66a_row2_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_4f66a_row1_col9, #T_4f66a_row4_col5, #T_4f66a_row4_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4f66a_row2_col4, #T_4f66a_row5_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_4f66a_row2_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_4f66a_row2_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4f66a_row3_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_4f66a_row3_col1, #T_4f66a_row3_col2, #T_4f66a_row4_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_4f66a_row3_col4, #T_4f66a_row4_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_4f66a_row3_col7, #T_4f66a_row5_col1, #T_4f66a_row5_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_4f66a_row3_col8, #T_4f66a_row4_col8 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_4f66a_row3_col9 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_4f66a_row4_col0, #T_4f66a_row8_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_4f66a_row4_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_4f66a_row4_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_4f66a_row4_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_4f66a_row5_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_4f66a_row5_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4f66a_row5_col6 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_4f66a_row5_col8, #T_4f66a_row6_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_4f66a_row6_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_4f66a_row6_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_4f66a_row6_col5 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_4f66a_row6_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_4f66a_row6_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4f66a_row7_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_4f66a_row7_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_4f66a_row7_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_4f66a_row7_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_4f66a_row7_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_4f66a_row7_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_4f66a_row7_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_4f66a_row7_col8 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_4f66a_row7_col9 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_4f66a_row8_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_4f66a_row8_col1, #T_4f66a_row8_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_4f66a_row8_col3 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_4f66a_row8_col4 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_4f66a_row8_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_4f66a_row8_col7 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_4f66a_row8_col9 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_4f66a_row9_col0, #T_4f66a_row9_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_4f66a_row9_col1, #T_4f66a_row9_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_4f66a_row9_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_4f66a_row9_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_4f66a_row9_col7 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_4f66a_row9_col8 {
#   background-color: #f7af91;
#   color: #000000;
# }
# </style>
# <table id="T_4f66a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ano</th>
#       <th class="col_heading level0 col1" >id_municipio</th>
#       <th class="col_heading level0 col2" >id_escola</th>
#       <th class="col_heading level0 col3" >taxa_aprovacao</th>
#       <th class="col_heading level0 col4" >indicador_rendimento</th>
#       <th class="col_heading level0 col5" >nota_saeb_matematica</th>
#       <th class="col_heading level0 col6" >nota_saeb_lingua_portuguesa</th>
#       <th class="col_heading level0 col7" >nota_saeb_media_padronizada</th>
#       <th class="col_heading level0 col8" >ideb</th>
#       <th class="col_heading level0 col9" >projecao</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f66a_level0_row0" class="row_heading level0 row0" >ano</th>
#       <td id="T_4f66a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4f66a_row0_col1" class="data row0 col1" >0.011018</td>
#       <td id="T_4f66a_row0_col2" class="data row0 col2" >0.010951</td>
#       <td id="T_4f66a_row0_col3" class="data row0 col3" >0.264246</td>
#       <td id="T_4f66a_row0_col4" class="data row0 col4" >0.267623</td>
#       <td id="T_4f66a_row0_col5" class="data row0 col5" >0.348161</td>
#       <td id="T_4f66a_row0_col6" class="data row0 col6" >0.393844</td>
#       <td id="T_4f66a_row0_col7" class="data row0 col7" >0.368267</td>
#       <td id="T_4f66a_row0_col8" class="data row0 col8" >0.405196</td>
#       <td id="T_4f66a_row0_col9" class="data row0 col9" >0.506271</td>
#     </tr>
#     <tr>
#       <th id="T_4f66a_level0_row1" class="row_heading level0 row1" >id_municipio</th>
#       <td id="T_4f66a_row1_col0" class="data row1 col0" >0.011018</td>
#       <td id="T_4f66a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4f66a_row1_col2" class="data row1 col2" >0.999820</td>
#       <td id="T_4f66a_row1_col3" class="data row1 col3" >0.164834</td>
#       <td id="T_4f66a_row1_col4" class="data row1 col4" >0.162383</td>
#       <td id="T_4f66a_row1_col5" class="data row1 col5" >0.261862</td>
#       <td id="T_4f66a_row1_col6" class="data row1 col6" >0.216358</td>
#       <td id="T_4f66a_row1_col7" class="data row1 col7" >0.306056</td>
#       <td id="T_4f66a_row1_col8" class="data row1 col8" >0.284877</td>
#       <td id="T_4f66a_row1_col9" class="data row1 col9" >0.287445</td>
#     </tr>
#     <tr>
#       <th id="T_4f66a_level0_row2" class="row_heading level0 row2" >id_escola</th>
#       <td id="T_4f66a_row2_col0" class="data row2 col0" >0.010951</td>
#       <td id="T_4f66a_row2_col1" class="data row2 col1" >0.999820</td>
#       <td id="T_4f66a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4f66a_row2_col3" class="data row2 col3" >0.163462</td>
#       <td id="T_4f66a_row2_col4" class="data row2 col4" >0.161040</td>
#       <td id="T_4f66a_row2_col5" class="data row2 col5" >0.259970</td>
#       <td id="T_4f66a_row2_col6" class="data row2 col6" >0.214760</td>
#       <td id="T_4f66a_row2_col7" class="data row2 col7" >0.304550</td>
#       <td id="T_4f66a_row2_col8" class="data row2 col8" >0.283216</td>
#       <td id="T
